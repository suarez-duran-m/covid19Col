# %%
from google.colab import drive
from os.path import join

# %%
ROOT = '/content/drive'     # default for the drive
PROJ = 'My Drive/laboral/proyectos/'       # path to your project on Drive

GIT_USERNAME = "suarez-duran-m" # replace with yours
GIT_TOKEN = "ed3abec840562d6958ddf8b942c027459658cc2b"           # definitely replace with yours
GIT_REPOSITORY = "suarez-duran-m/covid19Col"      # ...nah
GIT_PATH = "https://ed3abec840562d6958ddf8b942c027459658cc2b@github.com/suarez-duran-m/covid19Col.git"
drive.mount(ROOT)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
PROJECT_PATH = join(ROOT, PROJ)
#!mkdir "{PROJECT_PATH}"     # in case we haven't created it already
# !ls "{PROJECT_PATH}"
# Out:
# auger  covid19Col  halley  MuTe  space-weather	tmp

# %%
# %cd "{PROJECT_PATH}"/covid19Col
#!mkdir tmp
# !ls

#!git clone "{GIT_PATH}"
#!pwd
#!ls

# %%
# !ls -l covid19Col


# !ls
# Out:
# total 4
# -rw-r--r-- 1 root root 108 Apr  9 03:06 README.md
# /content/drive/My Drive/laboral/proyectos
# auger  covid19Col  halley  MuTe  space-weather	tmp

# %%
# %cd "{PROJECT_PATH}"/covid19Col

# !git config --global user.email "mauricio.suarez@unipamplona.edu.co"
# !git config --global user.name "suarez-duran-m"

# !git remote rm origin

# !git config --global github.user suarez-duran-m
# !git config --global github.token "{GIT_TOKEN}"

# !git add *
# !git commit -m "Primeras secciones de análisis agregadas."

# !git remote add origin https://"{GIT_TOKEN}"@github.com/"{GIT_REPOSITORY}".git

# !git push -u origin master
# Out:
# /content/drive/My Drive/laboral/proyectos/covid19Col
# [master b9786d4] Primeras secciones de análisis agregadas.
#  3 files changed, 2057 insertions(+)
#  create mode 100644 Casos1_08abr2020.csv
#  create mode 100644 cloningPushing.ipynb
#  create mode 100644 covid19Col.ipynb
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 77.34 KiB | 5.52 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0)
# To https://github.com/suarez-duran-m/covid19Col.git
#    1354270..b9786d4  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
